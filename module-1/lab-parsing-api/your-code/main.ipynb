# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
url= 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   NI122O0CE-C11  CLUB TEE - T-shirt basique - dark grey heather...
# 1   AD116D0QI-A11        SUPERSTAR - Baskets basses - footwear white
# 2   TO152B00S-K11                     CLASSIC - Casquette - midnight
# 3   C1422A006-802                   SID LAMAR - Chino - black rinsed
# 4   OS322E04A-K12      ONSMARK PANT - Pantalon classique - night sky
# ..            ...                                                ...
# 79  JOC42E02K-G11  JUMPMAN SHORT - Short de sport - gym red/gym r...
# 80  N1242A1UE-C11  REVOLUTION 5 - Chaussures de running neutres -...
# 81  PI922O0CI-A11                            T-shirt imprimé - white
# 82  TO122E04C-Q11  BASIC BRANDED  - Pantalon de survêtement - jet...
# 83  ES122G05Y-K12                        Jean droit - blue dark wash
#
#                                                 sizes  \
# 0                        [S, M, L, XL, XXL, 3XL, 4XL]
# 1                [19, 20, 21, 22, 23, 24, 25, 26, 27]
# 2                                          [One Size]
# 3   [27x32, 28x32, 30x32, 30x34, 30x36, 31x32, 31x...
# 4   [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# ..                                                ...
# 79                             [XS, S, M, L, XL, XXL]
# 80             [38.5, 39, 40, 40.5, 41, 42, 43, 44.5]
# 81                             [XS, S, M, L, XL, XXL]
# 82                                      [S, M, L, XL]
# 83  [29x32, 30x30, 30x32, 30x34, 31x30, 31x32, 31x...
#
#                                               url_key  \
# 0   nike-sportswear-club-tee-t-shirt-basique-ni122...
# 1   adidas-originals-superstar-baskets-basses-foot...
# 2      tommy-hilfiger-classic-casquette-to152b00s-k11
# 3             carhartt-lamar-chino-noir-c1422a006-802
# 4      only-and-sons-onsmark-pant-chino-os322e04a-k12
# ..                                                ...
# 79  jordan-jumpman-short-short-de-sport-gym-redgym...
# 80  nike-performance-revolution-5-chaussures-de-ru...
# 81       pier-one-t-shirt-imprime-white-pi922o0ci-a11
# 82  tommy-hilfiger-basic-branded-pantalon-de-surve...
# 83     esprit-jean-droit-blue-dark-wash-es122g05y-k12
#
#                                                 media        brand_name  \
# 0   [{'path': 'spp-media-p1/db1e495df38e38059b7549...   Nike Sportswear
# 1   [{'path': 'spp-media-p1/31ac62e7e9163571a977aa...  adidas Originals
# 2   [{'path': 'spp-media-p1/3ea1b4bd3cbe3d8d9608b9...    Tommy Hilfiger
# 3   [{'path': 'spp-media-p1/64eb4792dea5343cbb137f...      Carhartt WIP
# 4   [{'path': 'spp-media-p1/804480cc8c2c344fa0c490...       Only & Sons
# ..                                                ...               ...
# 79  [{'path': 'spp-media-p1/a51e4633df9236ac9994d8...            Jordan
# 80  [{'path': 'spp-media-p1/c63deec8fbe83ec3bc9610...  Nike Performance
# 81  [{'path': 'spp-media-p1/3c82c06caced3465bd7ab4...          Pier One
# 82  [{'path': 'spp-media-p1/20d98018446137a886d715...    Tommy Hilfiger
# 83  [{'path': 'spp-media-p1/9fe6c431e0913c09b1cd35...            Esprit
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': '-20%', 'tra...          shoe
# 2   [{'key': 'discountRate', 'value': '-15%', 'tra...   accessoires
# 3   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': 'Jusqu’à -15...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': 'Jusqu’à -10...      clothing
# 80  [{'key': 'discountRate', 'value': 'Jusqu’à -14...          shoe
# 81  [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-45%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': 'Jusqu’à -20...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        19,95 €           16,95 €
# 1                 []        54,95 €           43,95 €
# 2                 []        29,95 €           25,45 €
# 3                 []        89,95 €           76,45 €
# 4                 []        34,99 €           29,69 €
# ..               ...            ...               ...
# 79                []        33,95 €           30,55 €
# 80                []        54,95 €           47,16 €
# 81                []         9,99 €            8,49 €
# 82                []       109,95 €           60,95 €
# 83                []        49,99 €           39,99 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                         True                                False
# ..                         ...                                  ...
# 79                        True                                False
# 80                        True                                False
# 81                        True                                False
# 82                       False                                False
# 83                        True                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                    True
# 80                                    True
# 81                                    True
# 82                                   False
# 83                                    True
#
#     price.has_discount_on_selected_sizes_only outfits amount
# 0                                       False     NaN    NaN
# 1                                       False     NaN    NaN
# 2                                       False     NaN    NaN
# 3                                       False     NaN    NaN
# 4                                       False     NaN    NaN
# ..                                        ...     ...    ...
# 79                                      False     NaN    NaN
# 80                                      False     NaN  298 g
# 81                                      False     NaN    NaN
# 82                                      False     NaN    NaN
# 83                                      False     NaN    NaN
#
# [84 rows x 19 columns]

# %%
# Get the total number of pages

# Your code
df=pd.DataFrame()
for i in range(2):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages}", end='\r')

df
# Out:
# getting page 1 of 214
#                                                             name  \
# sku
# AD116D008-A11          STAN SMITH - Baskets basses - white/green
# LE226G007-C11  BATWING - T-shirt à manches longues - grey hea...
# AD116D07G-A11  STAN SMITH CF I - Chaussures premiers pas - wh...
# NI114D0CS-A11            COURT BOROUGH  - Baskets basses - white
# AD116D0MP-A11  STAN SMITH - Baskets basses - footwear white/c...
# ...                                                          ...
# PU116E00K-A11  SMASH LEATHER - Baskets basses - puma white-la...
# BL823K031-J11                                Sweatshirt - azalee
# M9123F0I5-A11                            PALS - Robe d'été - wit
# C7423G036-J11             KIDS WAIKI - T-shirt imprimé - fuchsia
# TO124I028-K11         BOYS SOLID STRETCH - Chemise - sky captain
#
#                                                            sizes  \
# sku
# AD116D008-A11           [36, 38, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# LE226G007-C11                       [6a, 8a, 10a, 12a, 14a, 16a]
# AD116D07G-A11               [19, 20, 21, 22, 23, 24, 25, 26, 27]
# NI114D0CS-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD116D0MP-A11  [36, 38, 40, 35 1/2, 36 2/3, 37 1/3, 38 2/3, 3...
# ...                                                          ...
# PU116E00K-A11                   [29, 31.5, 32, 33, 34, 34.5, 35]
# BL823K031-J11                                       [3a, 5a, 7a]
# M9123F0I5-A11                          [5a, 6a, 7a, 8a, 9a, 10a]
# C7423G036-J11                                    [12a, 14a, 16a]
# TO124I028-K11  [3a, 4a, 5a, 6a, 6-9m, 7a, 8a, 9-12m, 10a, 12a...
#
#                                                          url_key  \
# sku
# AD116D008-A11  adidas-originals-stan-smith-baskets-basses-bla...
# LE226G007-C11  levisr-batwing-tee-t-shirt-a-manches-longues-l...
# AD116D07G-A11  adidas-originals-stan-smith-cf-i-baskets-basse...
# NI114D0CS-A11  nike-sportswear-court-borough-baskets-basses-n...
# AD116D0MP-A11  adidas-originals-stan-smith-baskets-basses-foo...
# ...                                                          ...
# PU116E00K-A11  puma-smash-leather-baskets-basses-puma-white-l...
# BL823K031-J11         blue-seven-sweatshirt-azalee-bl823k031-j11
# M9123F0I5-A11             mango-pals-robe-dete-wit-m9123f0i5-a11
# C7423G036-J11  cars-jeans-kids-waiki-t-shirt-imprime-fuchsia-...
# TO124I028-K11  tommy-hilfiger-boys-solid-stretch-chemise-to12...
#
#                                                            media  \
# sku
# AD116D008-A11  [{'path': 'spp-media-p1/6e77790477903cb2943858...
# LE226G007-C11  [{'path': 'spp-media-p1/dd9fded32dde3b17b0486c...
# AD116D07G-A11  [{'path': 'spp-media-p1/ce39b604a97b373bbe8e46...
# NI114D0CS-A11  [{'path': 'spp-media-p1/0b5fec9e420b37099ccfe6...
# AD116D0MP-A11  [{'path': 'spp-media-p1/e35946364032394ea54a0f...
# ...                                                          ...
# PU116E00K-A11  [{'path': 'spp-media-p1/d24a7ee98ccc3aeb91464e...
# BL823K031-J11  [{'path': 'spp-media-p1/ad997a590b263d0d86aff7...
# M9123F0I5-A11  [{'path': 'spp-media-p1/f90fc439ee8c33c78831a2...
# C7423G036-J11  [{'path': 'spp-media-p1/98c57cc8feda3dcd8e9ce3...
# TO124I028-K11  [{'path': 'spp-media-p1/80c3bb27a7c93664822274...
#
#                      brand_name  is_premium family_articles  \
# sku
# AD116D008-A11  adidas Originals       False              []
# LE226G007-C11           Levi's®       False              []
# AD116D07G-A11  adidas Originals       False              []
# NI114D0CS-A11   Nike Sportswear       False              []
# AD116D0MP-A11  adidas Originals       False              []
# ...                         ...         ...             ...
# PU116E00K-A11              Puma       False              []
# BL823K031-J11        Blue Seven       False              []
# M9123F0I5-A11             Mango       False              []
# C7423G036-J11        Cars Jeans       False              []
# TO124I028-K11    Tommy Hilfiger       False              []
#
#                                                            flags  \
# sku
# AD116D008-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# LE226G007-C11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# AD116D07G-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# NI114D0CS-A11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# AD116D0MP-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -20...
# ...                                                          ...
# PU116E00K-A11  [{'key': 'discountRate', 'value': '-33%', 'tra...
# BL823K031-J11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# M9123F0I5-A11  [{'key': 'discountRate', 'value': '-33%', 'tra...
# C7423G036-J11  [{'key': 'discountRate', 'value': '-60%', 'tra...
# TO124I028-K11  [{'key': 'discountRate', 'value': 'Jusqu’à -17...
#
#               product_group delivery_promises price.original  \
# sku
# AD116D008-A11          shoe                []        64,95 €
# LE226G007-C11      clothing                []        21,95 €
# AD116D07G-A11          shoe                []        49,95 €
# NI114D0CS-A11          shoe                []        34,95 €
# AD116D0MP-A11          shoe                []        64,95 €
# ...                     ...               ...            ...
# PU116E00K-A11          shoe                []        45,00 €
# BL823K031-J11      clothing                []        14,95 €
# M9123F0I5-A11      clothing                []        29,99 €
# C7423G036-J11      clothing                []        19,95 €
# TO124I028-K11      clothing                []        49,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# AD116D008-A11           45,45 €                        True
# LE226G007-C11           16,45 €                        True
# AD116D07G-A11           37,45 €                        True
# NI114D0CS-A11           27,95 €                       False
# AD116D0MP-A11           51,95 €                        True
# ...                         ...                         ...
# PU116E00K-A11           29,95 €                       False
# BL823K031-J11            8,25 €                       False
# M9123F0I5-A11           19,99 €                       False
# C7423G036-J11            8,00 €                       False
# TO124I028-K11           41,35 €                        True
#
#                price.has_different_original_prices  \
# sku
# AD116D008-A11                                False
# LE226G007-C11                                False
# AD116D07G-A11                                False
# NI114D0CS-A11                                False
# AD116D0MP-A11                                False
# ...                                            ...
# PU116E00K-A11                                False
# BL823K031-J11                                False
# M9123F0I5-A11                                False
# C7423G036-J11                                False
# TO124I028-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# AD116D008-A11                                    True
# LE226G007-C11                                    True
# AD116D07G-A11                                    True
# NI114D0CS-A11                                   False
# AD116D0MP-A11                                    True
# ...                                               ...
# PU116E00K-A11                                   False
# BL823K031-J11                                   False
# M9123F0I5-A11                                   False
# C7423G036-J11                                   False
# TO124I028-K11                                    True
#
#                price.has_discount_on_selected_sizes_only amount
# sku
# AD116D008-A11                                      False    NaN
# LE226G007-C11                                      False    NaN
# AD116D07G-A11                                      False    NaN
# NI114D0CS-A11                                      False    NaN
# AD116D0MP-A11                                      False    NaN
# ...                                                  ...    ...
# PU116E00K-A11                                      False    NaN
# BL823K031-J11                                      False    NaN
# M9123F0I5-A11                                      False    NaN
# C7423G036-J11                                      False    NaN
# TO124I028-K11                                      False    NaN
#
# [168 rows x 17 columns]

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Nike Sportswear'

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
df.brand_name.value_counts().index[0]
# Out:
# 'Nike Sportswear'

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [str(x).replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [str(x).replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'adidas Performance'
